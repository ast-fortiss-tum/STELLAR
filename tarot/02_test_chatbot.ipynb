# %% [markdown]
# # Testing Natural Language Understanding of a Conversational In-Car Chatbot 🚗
#
# # Goal
#
# You are going to test the Natural Language Understanding (NLU) component of a task-oriented chatbot with STELLAR.
# Specifically, the goal is to generate natural language inputs that expose failures in the chatbot's intent recognition capabilities to control the climate control.
#
# ## What is a test input?
#
# A test input is a natural language utterance.
#
# ## What is a failure?
#
# A test is considered a failure, when the expected intent of an utterance, is not detected by the chatbot.
#
# Note: To simplify the overall task, there is no further parametrization of intents/slot filling performed.
#
# ## Example Pass
#
# - **Utterance:** "Can you start the fan?"
# - **Detected:** `INTENT_ActivateFan`
#
# ## Example Fail
#
# - **Utterance:** "I am freezing one's buns off!"
# - **Detected:** `INTENT_Unknown`
#
# ## Task
#
# Your task is to improve the notebooks and provide the following components to apply STELLAR to test NLU:
#
# 1. Utterance Generator (Prompts)
# 2. Fitness Function
#
# ## Ranking
#
# The results will be ranked based on the following criteria:
#
# - Fail Rate - number of failures divided by number of generated tests (the higher the better)
# - Diversity - number of different intents failed (the higher the better)
# - Number Tokens - number of input and output tokens spent for test generation (the lower the better)

# %% [markdown]
# # Getting Started
#
# Let's try out some utterancies to get familiar with the system and goal.
#
# Run the following command to start the chatbot. A browser window should pop up. You should be able to find the deployment otherwise here. You can send the chatbot utterance, and it will respond with intents.
#
# All possible intents that can be detected by assistant are provided here: [nlu_bot/intents.py](nlu_bot/intents.py)

# %%
from pathlib import Path; import subprocess, sys
app = next((p for p in (Path.cwd() / "nlu_bot" / "chatbot_app.py", Path.cwd() / "tarot" / "nlu_bot" / "chatbot_app.py", Path.cwd().parent / "tarot" / "nlu_bot" / "chatbot_app.py") if p.exists()), None)
subprocess.run([
    sys.executable,
    "-m",
    "streamlit",
    "run",
    str(app),
    "--server.showEmailPrompt",
    "false",
], check=True)
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.178.158:8501
#
# LLM raw output attempt 1/3: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.9},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02}]}
# LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.9},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02}]}
# 2026-07-13 17:04:28.239 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:04:34.655 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# LLM raw output attempt 1/3: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.9},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01}]}
# LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.9},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01}]}
# 2026-07-13 17:04:37.744 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:20.206 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:20.214 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# LLM raw output attempt 1/3: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02}]}
# LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02}]}
# 2026-07-13 17:05:23.356 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:29.503 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:29.511 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:29.523 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# LLM raw output attempt 1/3: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.8},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.4},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02}]}
# LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.8},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.4},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02}]}
# 2026-07-13 17:05:33.252 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:45.283 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:45.300 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:45.319 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-07-13 17:05:45.326 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# LLM raw output attempt 1/3: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.9},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01}]}
# LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.9},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01}]}
# 2026-07-13 17:05:48.654 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.

# %% [markdown]
# # Automated Testing
#
# Manually testing this chatbot is challenging. Let us apply STELLAR to test the bot.
#
# Run the following code to automatically generate the test cases.
#
# The generation should take 1 minute.

# %%
from pathlib import Path
script = next((p for p in (Path.cwd() / "run_test_script.sh", Path.cwd() / "tarot" / "run_test_script.sh", Path.cwd().parent / "tarot" / "run_test_script.sh", Path.cwd().parent.parent / "tarot" / "run_test_script.sh") if p.exists()), None)
# !bash {script}

# %% [markdown]
# # STELLAR Dashboard
#
# Let us visualize the results in a dashboard.

# %%
from pathlib import Path
import subprocess
import sys

dashboard = next((p for p in (Path.cwd() / "dashboard.py", Path.cwd().parent / "dashboard.py", Path.cwd().parent.parent / "dashboard.py") if p.exists()), None)
subprocess.run([
    sys.executable,
    "-m",
    "streamlit",
    "run",
    str(dashboard),
    "--server.port",
    "8501",
    "--server.address",
    "0.0.0.0",
    "--server.showEmailPrompt",
    "false",
], check=True)
# Out:
# /usr/bin/python3: No module named streamlit
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 6
#       3 import sys
#       5 dashboard = next((p for p in (Path.cwd() / "dashboard.py", Path.cwd().parent / "dashboard.py", Path.cwd().parent.parent / "dashboard.py") if p.exists()), None)
# ----> 6 subprocess.run([
#       7     sys.executable,
#       8     "-m",
#       9     "streamlit",
#      10     "run",
#      11     str(dashboard),
#      12     "--server.port",
#      13     "8501",
#      14     "--server.address",
#      15     "0.0.0.0",
#      16     "--server.showEmailPrompt",
#      17     "false",
#      18 ], check=True)
#
# File /usr/lib/python3.8/subprocess.py:516, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     514     retcode = process.poll()
#     515     if check and retcode:
# --> 516         raise CalledProcessError(retcode, process.args,
#     517                                  output=stdout, stderr=stderr)
#     518 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/usr/bin/python3', '-m', 'streamlit', 'run', '/home/lev/Documents/testing/ast-fortiss-tum/STELLAR/dashboard.py', '--server.port', '8501', '--server.address', '0.0.0.0', '--server.showEmailPrompt', 'false']' returned non-zero exit status 1.

# %% [markdown]
# # Your turn
#
# Now it is your turn: improve the implementation of the test generator to find more failures.
#
# Adjust the different notebooks below. You can just adjust some of the components if you are not sure
# about your implementation. Test your code at the end in step 4.

# %% [markdown]
# # 1. Utterance Generator

# %%
from pathlib import Path
import sys
from typing import Any, Dict

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents[:2]) if (p / "examples").exists() and (p / "tarot").exists()), None)

if project_root is None:
    raise FileNotFoundError("Could not locate the STELLAR project root")

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from examples.navi.models import StyleDescription
from tarot.misc.models import NLUContentInput
from tarot.misc.nlu_utterance_generator import NLUUtteranceGenerator
from tarot.nlu_bot.intents import INTENTS, INTENT_SET

PROMPT_GENERATOR = """ You are an intelligent user request generator to test an in car assistant."""
FALLBACK_INTENT = "INTENT_Unknown"

class CustomNLUUtteranceGenerator(NLUUtteranceGenerator):
    def build_style_prompt(
        self,
        feature_values: Dict[str, Any],
    ) -> str:
        num_words = "num_words"
        result = ""

        if num_words in feature_values:
            result += (
                f"The utterance must contain exactly "
                f"{feature_values[num_words]} words\n"
            )

        style_description = StyleDescription.model_validate(feature_values)

        result += style_description.model_dump_json(
            exclude_none=True,
            indent=2,
        )

        return "The linguistic and style features are:\n" + result

    def build_content_prompt(
        self,
        content_input: NLUContentInput,
    ) -> str:
        intent_name = (
            content_input.intent
            if content_input.intent in INTENT_SET
            else FALLBACK_INTENT
        )
        allowed_intents = "\n".join(
            f"- {intent}" for intent in INTENTS
        )

        return f"""
INTENT:
{intent_name}

ALLOWED_INTENTS:
{allowed_intents}

RULE:
Return one natural utterance expressing the intent.
Use only the selected intent above as semantic target.

The utterance should be shorter than 15 words.
Prefer shorter utterances.

Do not include variables or placeholders.

The language must be: ENGLISH
"""

    def build_perturbation_prompt(
        self,
        feature_values: Dict[str, Any],
    ) -> str:
        result = ""

        if "word_perturbation" in feature_values:
            if feature_values["word_perturbation"] == "introduce_fillers_llm_combined":
                result = """
Apply also at the very end the following perturbation:

Insert 1-2 natural filler words into the text
to make it sound more conversational and natural.

Return ONLY the modified text
with fillers inserted.

Use common English filler words like:
\"um\", \"uh\", \"well\", \"like\", \"you know\",
\"actually\", \"I mean\", \"sort of\", \"kind of\",
or others if you think they are relevant.

IMPORTANT:
- Insert fillers at natural pause points
(not in the middle of phrases)
- Keep the original meaning and flow
- Use fillers that fit the conversational tone
- Don't overuse fillers
- 1-2 insertions maximum
- Maintain original punctuation and capitalization
"""
            elif feature_values["word_perturbation"] == "introduce_homophones_llm_combined":
                result = """
At the very end, apply the following perturbation:

Replace at least one and at most two words
in the text with valid English homophones
(words that sound the same
but are spelled differently).

Return ONLY the modified text
with the substitutions applied.

Requirements:
- Use only real, valid homophones
- Preserve original capitalization
and punctuation
- If no suitable homophones are available,
return the text unchanged
"""

        return result

    def build_utterance_prompt(
        self,
        style_prompt_text: str,
        content_prompt_text: str,
        perturbation_prompt_text: str,
    ) -> str:
        return f"""You are an intelligent, human-like utterance generator and know how people talk. Your task is to generate natural utterances considering the style attributes, content, and perturbation features defined below.

Style:
{style_prompt_text}

Content:
{content_prompt_text}

Perturbations:
{perturbation_prompt_text}

Guidelines:
- Styles:
    Slang (Slangy):
    Use German slang or colloquial expressions.

    Examples:
    - \"Where can I grab some food?\"
    - \"Take me to the nearest spot.\"
    - \"I need a place to chill.\"


    Implicit (Implicit):
    Ask indirectly without naming the venue explicitly.

    Examples:
    - \"Where can I still get something warm?\"
    - \"My car is making strange noises.\"
    - \"I need somewhere to sleep.\"


    Politeness (Rude):
    Sound unfriendly, impatient, or insulting.

    Examples:
    - \"Hurry up already.\"
    - \"Where is that damn place?\"
    - \"Start driving now.\"


    Anthropomorphism (very directive):
    Make the utterance very short and directive.

    Examples:
    - \"To the station.\"
    - \"Nearest gas station.\"
    - \"Hospital now.\"

Return only one utterance.
"""

    def build_system_prompt(self) -> str:
        return PROMPT_GENERATOR

# %% [markdown]
# # 2. Fitness Function

# %%
from typing import Tuple

from opensbt.evaluation.fitness import Fitness
from llm.model.qa_simout import QASimulationOutput
from llm.utils.embeddings_openai import get_similarity
from tarot.nlu_bot.intents import INTENT_SET

FALLBACK_INTENT = "INTENT_Unknown"

"""
The fitness function defines which objectives to optimize to find failures.
You can add an objective by using e.g. the confidence in the prediction to direct the search.
Dont forget: Adjust the fitness name, the min_max direction, if you add another objective.
"""

class CustomIntentMatchFitness(Fitness):

    def __init__(self, llm_type=None):
        self.llm_type = llm_type
        super().__init__()

    @property
    def min_or_max(self):
        """Return 'min' if the fitness should be minimized, 'max' if it should be maximized.
           For each objective assign on direction.
        """
        return ("min",)

    @property
    def name(self):
        """Name of the objective. You can add multiple objectives by returning a tuple of names."""
        return ("intent_match_score",)

    # ------------------------------------------------------------
    # EVALUATION
    # ------------------------------------------------------------
    def _evaluate(
        self,
        simout: QASimulationOutput,
    ) -> Tuple[float, dict]:

        """ This fitness function evaluates right now the intent match and returns the embeddings distance
            between predicted and expected intent.
        """

        raw = simout.utterance.raw_output
        content_input = simout.utterance.content_input

        if raw is None or content_input is None:
            return 1.0, {}

        # the predicted intent
        pred_intent = raw.get("intent", FALLBACK_INTENT)
        
        # the highest prediction certainty (not used right now)
        certainty = raw.get("certainty")

        # the expected intent
        true_intent = getattr(content_input, "intent", None)

        # all intent confidences (not used right now)
        # "intent_confidences": [
        #     {
        #         "intent": "INTENT_ActivateAirConditioning",
        #         "confidence": 0.05
        #     },
        #     {
        #         "intent": "INTENT_ActivateClimateSync",
        #         "confidence": 0.05
        #     },
        # ]
        all_intent_confidences =  raw.get("intent_confidences")

        if pred_intent not in INTENT_SET:
            pred_intent = FALLBACK_INTENT

        if pred_intent != true_intent:
            sim = get_similarity(pred_intent, true_intent)
            debug = {
                "certainty": certainty,
            }
            return float(sim), debug

        debug = {
            "certainty": certainty,
        }
        return 1.0, debug

    # ------------------------------------------------------------
    # PUBLIC API
    # ------------------------------------------------------------
    def eval(
        self,
        simout: QASimulationOutput,
        **kwargs,
    ) -> Tuple[float]:

        if simout is None or simout.utterance is None:
            return (1.0,)

        score, debug = self._evaluate(
            simout
        )
    
        # We add debug information for the analysis
        if simout.utterance.raw_output is not None:
            simout.utterance.raw_output[
                "_fitness_debug"
            ] = debug

        # The final score
        return (score,)

# %% [markdown]
# # 3. Test Your Implementation
#
# Run the following cells to test your implementation.
# There are no changes to the code required.
#
# When the execution is finished, you should see a final output like this:
# ```json
# {
#     "fail_rate": 0.0,
#     "num_diverse_fails": 0,
#     "tokens_spent": 117746
# }
# ```

# %%
# Set the test parameters first to try different search configurations

population_size = 5           # number of tests per generation
max_time = "00:01:00"         # total execution time for the search, e.g., "00:00:10" for 10 seconds
n_generations = 20            # if max_time is set, n_generations will be ignored
seed = 1

# %% [markdown]
# Run your code by executing the cell below.

# %%
from argparse import Namespace
import csv
import json
import os
from pathlib import Path
import sys
import warnings

import wandb
from opensbt.algorithm.nsga2_optimizer import NsgaIIOptimizer
from opensbt.algorithm.ps_rand import PureSamplingRand
from opensbt.config import LOG_FILE
from opensbt.utils.log_utils import (
    disable_pymoo_warnings,
    log,
    setup_logging,
 )

candidate_roots = [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]
project_root = next((path for path in candidate_roots if (path / "llm").exists()), None)

if project_root is None:
    raise FileNotFoundError("Could not locate the STELLAR project root")

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

os.chdir(project_root)

from llm.eval.critical import CriticalByFitnessThreshold, CriticalMerged
from llm.llms import LLMType
from llm.model.qa_problem import QAProblem
from llm.model.search_configuration import QASearchConfiguration, QASearchOperators
from llm.operators.utterance_crossover_discrete import UtteranceCrossoverDiscrete
from llm.operators.utterance_duplicates import UtteranceDuplicateEliminationDistance
from llm.operators.utterance_mutator_discrete import UtteranceMutationDiscrete
from llm.operators.utterance_repair import UtteranceRepairQuestionGenerator
from llm.operators.utterance_sampling_discrete import (
    UtteranceSamplingDiscrete,
    UtteranceSamplingGrid,
 )
from tarot.nlu_bot.ipa_nlu_bot import IPA_NLU_BOT

def configure_runtime() -> None:
    warnings.filterwarnings("ignore", category=FutureWarning)
    setup_logging(LOG_FILE)
    disable_pymoo_warnings()
    if wandb.run is None:
        wandb.init(mode="disabled")

def build_search_config(args):
    llm_generator = LLMType(args.generator)

    operators = QASearchOperators(
        crossover=UtteranceCrossoverDiscrete(
            llm_type=llm_generator,
            generate_question=True,
        ),
        sampling=(
            UtteranceSamplingGrid(
                llm_type=llm_generator,
                total_samples=args.population_size,
                t=4,
            )
            if args.algorithm == "random"
            else UtteranceSamplingDiscrete(
                llm_type=llm_generator,
                generate_question=True,
            )
        ),
        mutation=UtteranceMutationDiscrete(
            llm_type=llm_generator,
            generate_question=True,
        ),
        duplicate_elimination=UtteranceDuplicateEliminationDistance(),
        repair=UtteranceRepairQuestionGenerator(llm_type=llm_generator),
    )

    config = QASearchConfiguration(operators=operators)
    config.population_size = args.population_size
    config.n_generations = args.n_generations
    config.maximal_execution_time = args.max_time
    config.results_folder = args.results_folder
    return config

def build_optimizer(args, problem, config):
    if args.algorithm == "nsga2":
        return NsgaIIOptimizer(problem=problem, config=config)

    if args.algorithm == "random":
        return PureSamplingRand(problem=problem, config=config)

    raise ValueError("Unknown algorithm")

def report_execution_metrics(results_folder: str) -> dict:
    results_path = Path(results_folder)

    summary_results_path = results_path / "summary_results.csv"
    all_critical_utterances_path = results_path / "all_critical_utterances.json"
    llm_usage_summary_path = results_path / "llm_usage_summary.json"

    fail_rate = None
    with summary_results_path.open("r", encoding="utf-8", newline="") as csv_file:
        for row in csv.DictReader(csv_file):
            if row.get("Attribute") == "Ratio Critical/All scenarios (duplicate free)":
                fail_rate = float(row["Value"])
                break

    if fail_rate is None:
        raise ValueError(
            "Could not find 'Ratio Critical/All scenarios (duplicate free)' in summary_results.csv"
        )

    with all_critical_utterances_path.open("r", encoding="utf-8") as json_file:
        all_critical_utterances = json.load(json_file)

    diverse_intents = set()
    for entry in all_critical_utterances:
        utterance = entry.get("utterance", {})
        content_input = utterance.get("content_input", {})
        intent = content_input.get("intent")
        if intent:
            diverse_intents.add(intent)

    with llm_usage_summary_path.open("r", encoding="utf-8") as json_file:
        llm_usage_summary = json.load(json_file)

    tokens_spent = llm_usage_summary["total"]["tokens"]

    metrics = {
        "fail_rate": fail_rate,
        "num_diverse_fails": len(diverse_intents),
        "tokens_spent": tokens_spent,
    }

    metrics_path = results_path / "execution_metrics.json"
    with metrics_path.open("w", encoding="utf-8") as json_file:
        json.dump(metrics, json_file, indent=4)

    print(json.dumps(metrics, indent=4))
    return metrics

feature_config_path = project_root / "tarot" / "configs" / "features_nlu.json"

args = Namespace(
    population_size=population_size,
    n_generations=n_generations,
    seed=seed,
    max_time=max_time,
    algorithm="nsga2",
    results_folder="results",
    features_config=str(feature_config_path),
    generator=LLMType.GPT_4O_MINI,
 )

configure_runtime()
log.info("Starting notebook NLU search experiment")

config = build_search_config(args)
fitness = CustomIntentMatchFitness()
critical = CriticalMerged(
    fitness_names=fitness.name,
    criticals=[
        (CriticalByFitnessThreshold(mode="<", score=1), ["intent_match_score"]),
    ],
    mode="or",
 )

problem = QAProblem(
    problem_name=(
        f"NLU_test_{args.algorithm}_p{config.population_size}"
        f"_g{config.n_generations}_t-{args.max_time}_s{args.seed}"
    ).replace(":", "-").replace("/", "-"),
    scenario_path=str(project_root),
    xl=[0],
    xu=[1],
    simulation_variables=["utterance"],
    fitness_function=fitness,
    critical_function=critical,
    simulate_function=IPA_NLU_BOT.simulate,
    seed_utterances=["play some radio"],
    context={},
    seed=args.seed,
    names_dim_utterance=["utterance"],
    feature_handler_config_path=str(feature_config_path),
    question_generator=CustomNLUUtteranceGenerator(),
 )

optimizer = build_optimizer(args, problem, config)
result = optimizer.run()
result.write_results(
    results_folder=optimizer.save_folder,
    params=optimizer.parameters,
    search_config=config,
 )

results_root = Path(optimizer.save_folder)
if results_root.is_absolute():
    try:
        results_root = results_root.relative_to(project_root)
    except ValueError:
        results_root = Path(os.path.relpath(results_root, project_root))
os.environ["STELLAR_RESULTS_ROOT"] = str(results_root)

metrics = report_execution_metrics(optimizer.save_folder)
# Out:
# 2026-07-14 00:02:59,893 INFO     Logging setup. Writing to file:  ./log.txt
# 2026-07-14 00:02:59,894 INFO     Starting notebook NLU search experiment
# [create save folder] path: results
# [Optimizer] save_folder created: ./results/NLU_test_nsga2_p5_g20_t-00-01-00_s1/NSGA-II/14-07-2026_00-02-59/
# 2026-07-14 00:03:00,638 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 92
# 2026-07-14 00:03:00,639 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 55790
# 2026-07-14 00:03:01,354 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 93
# 2026-07-14 00:03:01,355 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 56374
# 2026-07-14 00:03:02,070 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 94
# 2026-07-14 00:03:02,073 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 56961
# 2026-07-14 00:03:02,787 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 95
# 2026-07-14 00:03:02,789 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 57156
# 2026-07-14 00:03:04,117 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 96
# 2026-07-14 00:03:04,118 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 57743
# 2026-07-14 00:03:04,835 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 97
# 2026-07-14 00:03:04,837 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 57941
# 2026-07-14 00:03:05,447 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 98
# 2026-07-14 00:03:05,448 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 58526
# 2026-07-14 00:03:05,453 INFO     Running evaluation number 1
# 2026-07-14 00:03:05,454 INFO     context: {}
# 2026-07-14 00:03:05,455 INFO     [IPA_NLU_BOT] list_individuals: [[Utterance(question='Turn on the seat cooling.', answer=None, seed=None, ordinal_vars=[0.5617398334655865, 0.2927058121303151, 0.16761687754460056, 0.38967245711143794], categorical_vars=[3, 0], content_input=NLUContentInput(intent='INTENT_ActivateSeatCooling'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Um, turn on the seat heating, please.', answer=None, seed=None, ordinal_vars=[0.9894205252397991, 0.23077420522310468, 0.9736516658759619, 0.00976369580822059], categorical_vars=[4, 2], content_input=NLUContentInput(intent='INTENT_ActivateSeatHeating'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Could you, um, please turn on the air conditioning?', answer=None, seed=None, ordinal_vars=[0.14036920833501737, 0.8443884283243389, 0.5788789077515157, 0.7086564179743432], categorical_vars=[0, 2], content_input=NLUContentInput(intent='INTENT_ActivateAirConditioning'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Turn off climate sync.', answer=None, seed=None, ordinal_vars=[0.9160552181266131, 0.26309310948382947, 0.11197338154397629, 0.8234035370934198], categorical_vars=[7, 0], content_input=NLUContentInput(intent='INTENT_DeactivateClimateSync'), content_output_list=[], raw_output=None)]]
# 2026-07-14 00:03:05,455 INFO     [IPA_NLU_BOT] Utterance already in memory: Turn on the seat cooling.
# 2026-07-14 00:03:05,456 INFO     [IPA_NLU_BOT] Utterance already in memory: Um, turn on the seat heating, please.
# 2026-07-14 00:03:05,457 INFO     [IPA_NLU_BOT] Utterance already in memory: Could you, um, please turn on the air conditioning?
# 2026-07-14 00:03:05,457 INFO     [IPA_NLU_BOT] Utterance already in memory: Turn off climate sync.
# 0.9189597513290261
# 2026-07-14 00:03:06,572 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 99
# 2026-07-14 00:03:06,573 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 59111
# 2026-07-14 00:03:07,293 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 100
# 2026-07-14 00:03:07,295 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 59302
# 2026-07-14 00:03:07,916 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 101
# 2026-07-14 00:03:07,918 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 59891
# 2026-07-14 00:03:08,727 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 102
# 2026-07-14 00:03:08,729 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 60087
# 2026-07-14 00:03:09,444 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 103
# 2026-07-14 00:03:09,445 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 60674
# 2026-07-14 00:03:10,165 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 104
# 2026-07-14 00:03:10,167 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 60869
# 2026-07-14 00:03:10,878 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 105
# 2026-07-14 00:03:10,879 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 61456
# 2026-07-14 00:03:11,594 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 106
# 2026-07-14 00:03:11,596 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 61651
# 2026-07-14 00:03:12,209 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 107
# 2026-07-14 00:03:12,210 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 62238
# 2026-07-14 00:03:12,926 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 108
# 2026-07-14 00:03:12,927 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 62433
# 2026-07-14 00:03:13,581 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 109
# 2026-07-14 00:03:13,582 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 63021
# 2026-07-14 00:03:14,359 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 110
# 2026-07-14 00:03:14,361 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 63216
# 1 mutation calls
# 2026-07-14 00:03:14,973 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 111
# 2026-07-14 00:03:14,975 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 63801
# 2026-07-14 00:03:15,691 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 112
# 2026-07-14 00:03:15,692 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 63992
# 2026-07-14 00:03:16,305 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 113
# 2026-07-14 00:03:16,307 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 64578
# 2026-07-14 00:03:17,019 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 114
# 2026-07-14 00:03:17,020 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 64767
# 2026-07-14 00:03:17,636 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 115
# 2026-07-14 00:03:17,638 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 65352
# 2026-07-14 00:03:18,250 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 116
# 2026-07-14 00:03:18,252 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 65543
# 2026-07-14 00:03:18,972 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 117
# 2026-07-14 00:03:18,973 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 66130
# 2026-07-14 00:03:19,790 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 118
# 2026-07-14 00:03:19,791 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 66325
# 2026-07-14 00:03:20,504 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 119
# 2026-07-14 00:03:20,504 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 66911
# 2026-07-14 00:03:21,220 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 120
# 2026-07-14 00:03:21,222 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 67105
# 2026-07-14 00:03:21,892 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 121
# 2026-07-14 00:03:21,893 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 67692
# 2026-07-14 00:03:22,657 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 122
# 2026-07-14 00:03:22,659 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 67887
# 2026-07-14 00:03:23,343 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 123
# 2026-07-14 00:03:23,344 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 68474
# 2026-07-14 00:03:23,985 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 124
# 2026-07-14 00:03:23,987 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 68665
# 2026-07-14 00:03:24,597 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 125
# 2026-07-14 00:03:24,599 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 69250
# 2026-07-14 00:03:25,214 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 126
# 2026-07-14 00:03:25,215 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 69441
# 2026-07-14 00:03:25,827 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 127
# 2026-07-14 00:03:25,830 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 70028
# 2026-07-14 00:03:26,649 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 128
# 2026-07-14 00:03:26,650 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 70219
# 2026-07-14 00:03:28,080 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 129
# 2026-07-14 00:03:28,082 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 70802
# 2 mutation calls
# 2026-07-14 00:03:29,411 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 130
# 2026-07-14 00:03:29,412 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 71388
# 2026-07-14 00:03:30,041 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 131
# 2026-07-14 00:03:30,043 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 71971
# 2026-07-14 00:03:30,635 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 132
# 2026-07-14 00:03:30,637 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 72558
# 2026-07-14 00:03:31,254 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 133
# 2026-07-14 00:03:31,255 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 73142
# 2026-07-14 00:03:31,972 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 134
# 2026-07-14 00:03:31,974 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 73729
# 2026-07-14 00:03:32,789 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 135
# 2026-07-14 00:03:32,790 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 74319
# 2026-07-14 00:03:33,838 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 136
# 2026-07-14 00:03:33,840 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 74521
# 3 mutation calls
# 2026-07-14 00:03:34,530 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 137
# 2026-07-14 00:03:34,531 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 75107
# 2026-07-14 00:03:35,351 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 138
# 2026-07-14 00:03:35,352 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 75697
# 2026-07-14 00:03:36,059 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 139
# 2026-07-14 00:03:36,060 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 75897
# 2026-07-14 00:03:36,103 INFO     Running evaluation number 2
# 2026-07-14 00:03:36,104 INFO     context: {}
# 2026-07-14 00:03:36,104 INFO     [IPA_NLU_BOT] list_individuals: [[Utterance(question='Um, activate seat heating, please.', answer=None, seed='Um, turn on the seat heating, please.', ordinal_vars=[0.98, 0.23, 0.97, 0.01], categorical_vars=[4, 2], content_input=NLUContentInput(intent='INTENT_ActivateSeatHeating'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Cool my seat.', answer=None, seed='Um, turn on the seat cooler.', ordinal_vars=[0.99, 0.23, 0.2, 0.4], categorical_vars=[3, 0], content_input=NLUContentInput(intent='INTENT_ActivateSeatCooling'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Turn on the seat heater.', answer=None, seed='Um, turn on the seat heater.', ordinal_vars=[0.92, 0.26, 0.09, 0.75], categorical_vars=[4, 1], content_input=NLUContentInput(intent='INTENT_ActivateSeatHeating'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Please set the fan speed to medium.', answer=None, seed='Please activate the seat heating.', ordinal_vars=[0.56, 0.23, 0.97, 0.39], categorical_vars=[20, 0], content_input=NLUContentInput(intent='INTENT_SetFanSpeed'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Could you, um, please turn off climate sync for me?', answer=None, seed='Could you, um, please turn off the climate sync for me?', ordinal_vars=[0.92, 0.23, 0.98, 0.83], categorical_vars=[7, 2], content_input=NLUContentInput(intent='INTENT_DeactivateClimateSync'), content_output_list=[], raw_output=None)]]
# 2026-07-14 00:03:38,936 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 140
# 2026-07-14 00:03:38,937 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 76943
# 2026-07-14 00:03:38,939 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01},{intent_index:24,confidence:0.01}]}
# 2026-07-14 00:03:38,957 INFO     [IPA_NLU_BOT] Success: Um, activate seat heating, please. -> INTENT_ActivateAirConditioning (0.01)
# 2026-07-14 00:03:41,803 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 141
# 2026-07-14 00:03:41,804 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 77985
# 2026-07-14 00:03:41,806 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.85},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01},{intent_index:24,confidence:0.01}]}
# 2026-07-14 00:03:41,814 INFO     [IPA_NLU_BOT] Success: Cool my seat. -> INTENT_ActivateSeatCooling (0.85)
# 2026-07-14 00:03:44,874 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 142
# 2026-07-14 00:03:44,875 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 79029
# 2026-07-14 00:03:44,875 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01},{intent_index:24,confidence:0.01}]}
# 2026-07-14 00:03:44,884 INFO     [IPA_NLU_BOT] Success: Turn on the seat heater. -> INTENT_ActivateAirConditioning (0.01)
# 2026-07-14 00:03:47,947 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 143
# 2026-07-14 00:03:47,949 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 80075
# 2026-07-14 00:03:47,951 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.1},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.8},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02},{intent_index:24,confidence:0.02}]}
# 2026-07-14 00:03:47,974 INFO     [IPA_NLU_BOT] Success: Please set the fan speed to medium. -> INTENT_SetFanSpeed (0.80)
# 2026-07-14 00:03:51,224 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 144
# 2026-07-14 00:03:51,225 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 81126
# 2026-07-14 00:03:51,227 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.8},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02},{intent_index:24,confidence:0.02}]}
# 2026-07-14 00:03:51,234 INFO     [IPA_NLU_BOT] Success: Could you, um, please turn off climate sync for me? -> INTENT_DeactivateClimateSync (0.80)
# 0.9189597513290261
# 0.9189597513290261
# 2026-07-14 00:03:53,067 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 145
# 2026-07-14 00:03:53,069 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 81713
# 2026-07-14 00:03:53,681 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 146
# 2026-07-14 00:03:53,683 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 82298
# 2026-07-14 00:03:54,285 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 147
# 2026-07-14 00:03:54,287 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 82489
# 2026-07-14 00:03:55,013 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 148
# 2026-07-14 00:03:55,014 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 83076
# 2026-07-14 00:03:55,730 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 149
# 2026-07-14 00:03:55,732 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 83271
# 2026-07-14 00:03:56,334 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 150
# 2026-07-14 00:03:56,335 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 83858
# 2026-07-14 00:03:56,959 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 151
# 2026-07-14 00:03:56,960 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 84445
# 2026-07-14 00:03:57,676 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 152
# 2026-07-14 00:03:57,677 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 84640
# 2026-07-14 00:03:58,494 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 153
# 2026-07-14 00:03:58,496 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 85227
# 4 mutation calls
# 2026-07-14 00:03:59,211 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 154
# 2026-07-14 00:03:59,213 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 85814
# 2026-07-14 00:04:00,029 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 155
# 2026-07-14 00:04:00,030 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 86401
# 2026-07-14 00:04:00,851 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 156
# 2026-07-14 00:04:00,853 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 86601
# 2026-07-14 00:04:01,567 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 157
# 2026-07-14 00:04:01,568 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 87188
# 2026-07-14 00:04:02,180 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 158
# 2026-07-14 00:04:02,181 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 87775
# 2026-07-14 00:04:03,000 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 159
# 2026-07-14 00:04:03,002 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 88362
# 2026-07-14 00:04:03,717 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 160
# 2026-07-14 00:04:03,718 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 88557
# 2026-07-14 00:04:04,360 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 161
# 2026-07-14 00:04:04,361 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 89144
# 2026-07-14 00:04:05,048 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 162
# 2026-07-14 00:04:05,050 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 89731
# 2026-07-14 00:04:05,765 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 163
# 2026-07-14 00:04:05,767 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 89926
# 2026-07-14 00:04:06,482 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 164
# 2026-07-14 00:04:06,484 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 90516
# 2026-07-14 00:04:07,197 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 165
# 2026-07-14 00:04:07,198 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 90718
# 2026-07-14 00:04:07,815 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 166
# 2026-07-14 00:04:07,816 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 91305
# 2026-07-14 00:04:08,530 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 167
# 2026-07-14 00:04:08,532 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 91500
# 2026-07-14 00:04:09,247 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 168
# 2026-07-14 00:04:09,248 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 92088
# 2026-07-14 00:04:09,964 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 169
# 2026-07-14 00:04:09,965 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 92286
# 5 mutation calls
# 2026-07-14 00:04:10,679 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 170
# 2026-07-14 00:04:10,680 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 92873
# 2026-07-14 00:04:11,397 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 171
# 2026-07-14 00:04:11,399 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 93464
# 2026-07-14 00:04:12,114 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 172
# 2026-07-14 00:04:12,116 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 93664
# 2026-07-14 00:04:13,141 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 173
# 2026-07-14 00:04:13,142 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 94251
# 2026-07-14 00:04:13,853 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 174
# 2026-07-14 00:04:13,854 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 94842
# 2026-07-14 00:04:14,567 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 175
# 2026-07-14 00:04:14,568 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 95044
# 2026-07-14 00:04:15,289 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 176
# 2026-07-14 00:04:15,291 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 95634
# 2026-07-14 00:04:15,902 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 177
# 2026-07-14 00:04:15,903 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 96219
# 2026-07-14 00:04:16,723 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 178
# 2026-07-14 00:04:16,724 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 96809
# 2026-07-14 00:04:17,437 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 179
# 2026-07-14 00:04:17,438 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 97395
# 6 mutation calls
# 2026-07-14 00:04:18,053 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 180
# 2026-07-14 00:04:18,054 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 97982
# 2026-07-14 00:04:18,769 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 181
# 2026-07-14 00:04:18,769 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 98566
# 2026-07-14 00:04:19,489 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 182
# 2026-07-14 00:04:19,490 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 99155
# 2026-07-14 00:04:20,162 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 183
# 2026-07-14 00:04:20,164 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 99742
# 2026-07-14 00:04:20,920 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 184
# 2026-07-14 00:04:20,921 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 99937
# 2026-07-14 00:04:21,841 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 185
# 2026-07-14 00:04:21,843 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 100522
# 2026-07-14 00:04:22,659 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 186
# 2026-07-14 00:04:22,660 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 100718
# 2026-07-14 00:04:23,379 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 187
# 2026-07-14 00:04:23,381 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 101306
# 2026-07-14 00:04:24,300 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 188
# 2026-07-14 00:04:24,301 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 101504
# 7 mutation calls
# 2026-07-14 00:04:25,005 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 189
# 2026-07-14 00:04:25,007 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 102089
# 2026-07-14 00:04:25,735 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 190
# 2026-07-14 00:04:25,737 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 102285
# 2026-07-14 00:04:26,348 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 191
# 2026-07-14 00:04:26,350 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 102873
# 2026-07-14 00:04:26,414 INFO     Running evaluation number 3
# 2026-07-14 00:04:26,415 INFO     context: {}
# 2026-07-14 00:04:26,416 INFO     [IPA_NLU_BOT] list_individuals: [[Utterance(question='Set the temperature to, um, 72 degrees, please.', answer=None, seed='Um, activate seat heating, please.', ordinal_vars=[0.98, 0.23, 0.97, 0.01], categorical_vars=[23, 2], content_input=NLUContentInput(intent='INTENT_SetTemperature'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Could you, um, please turn off the steering wheel heating?', answer=None, seed='Could you, um, please turn on the seat heating for me?', ordinal_vars=[0.98, 0.23, 0.97, 0.79], categorical_vars=[11, 2], content_input=NLUContentInput(intent='INTENT_DeactivateSteeringWheelHeating'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Cool down the seat.', answer=None, seed='Cool my seat.', ordinal_vars=[0.99, 0.23, 0.2, 0.4], categorical_vars=[3, 1], content_input=NLUContentInput(intent='INTENT_ActivateSeatCooling'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Could you please turn on the seat heater?', answer=None, seed='Could you please turn on the seat heating for me?', ordinal_vars=[0.92, 0.26, 0.97, 0.76], categorical_vars=[4, 0], content_input=NLUContentInput(intent='INTENT_ActivateSeatHeating'), content_output_list=[], raw_output=None)]
#  [Utterance(question='Could you, um, please lower the seat heating?', answer=None, seed='Could you, um, please activate the seat heating?', ordinal_vars=[0.14, 0.84, 0.58, 0.69], categorical_vars=[14, 2], content_input=NLUContentInput(intent='INTENT_DecreaseSeatHeating'), content_output_list=[], raw_output=None)]]
# 2026-07-14 00:04:29,420 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 192
# 2026-07-14 00:04:29,422 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 103924
# 2026-07-14 00:04:29,424 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.8},{intent_index:24,confidence:0.02}]}
# 2026-07-14 00:04:29,433 INFO     [IPA_NLU_BOT] Success: Set the temperature to, um, 72 degrees, please. -> INTENT_SetTemperature (0.80)
# 2026-07-14 00:04:32,390 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 193
# 2026-07-14 00:04:32,392 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 104975
# 2026-07-14 00:04:32,394 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.9},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.02},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02},{intent_index:24,confidence:0.02}]}
# 2026-07-14 00:04:32,406 INFO     [IPA_NLU_BOT] Success: Could you, um, please turn off the steering wheel heating? -> INTENT_DeactivateSteeringWheelHeating (0.90)
# 2026-07-14 00:04:35,279 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 194
# 2026-07-14 00:04:35,280 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 106018
# 2026-07-14 00:04:35,281 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.85},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01},{intent_index:24,confidence:0.01}]}
# 2026-07-14 00:04:35,293 INFO     [IPA_NLU_BOT] Success: Cool down the seat. -> INTENT_ActivateSeatCooling (0.85)
# 2026-07-14 00:04:38,534 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 195
# 2026-07-14 00:04:38,535 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 107065
# 2026-07-14 00:04:38,536 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.01},{intent_index:1,confidence:0.01},{intent_index:2,confidence:0.01},{intent_index:3,confidence:0.01},{intent_index:4,confidence:0.01},{intent_index:5,confidence:0.01},{intent_index:6,confidence:0.01},{intent_index:7,confidence:0.01},{intent_index:8,confidence:0.01},{intent_index:9,confidence:0.01},{intent_index:10,confidence:0.01},{intent_index:11,confidence:0.01},{intent_index:12,confidence:0.01},{intent_index:13,confidence:0.01},{intent_index:14,confidence:0.01},{intent_index:15,confidence:0.01},{intent_index:16,confidence:0.01},{intent_index:17,confidence:0.01},{intent_index:18,confidence:0.01},{intent_index:19,confidence:0.01},{intent_index:20,confidence:0.01},{intent_index:21,confidence:0.01},{intent_index:22,confidence:0.01},{intent_index:23,confidence:0.01},{intent_index:24,confidence:0.01}]}
# 2026-07-14 00:04:38,546 INFO     [IPA_NLU_BOT] Success: Could you please turn on the seat heater? -> INTENT_ActivateAirConditioning (0.01)
# 2026-07-14 00:04:41,811 INFO     [Overview] LLM LLMType.GPT_4O_MINI calls: 196
# 2026-07-14 00:04:41,812 INFO     [Overview] LLM LLMType.GPT_4O_MINI token usage: 108114
# 2026-07-14 00:04:41,813 INFO     [IPA_NLU_BOT] Attempt 1/5 raw LLM output: {intent_confidences:[{intent_index:0,confidence:0.02},{intent_index:1,confidence:0.02},{intent_index:2,confidence:0.02},{intent_index:3,confidence:0.02},{intent_index:4,confidence:0.02},{intent_index:5,confidence:0.02},{intent_index:6,confidence:0.02},{intent_index:7,confidence:0.02},{intent_index:8,confidence:0.02},{intent_index:9,confidence:0.02},{intent_index:10,confidence:0.02},{intent_index:11,confidence:0.02},{intent_index:12,confidence:0.02},{intent_index:13,confidence:0.02},{intent_index:14,confidence:0.8},{intent_index:15,confidence:0.02},{intent_index:16,confidence:0.02},{intent_index:17,confidence:0.02},{intent_index:18,confidence:0.02},{intent_index:19,confidence:0.02},{intent_index:20,confidence:0.02},{intent_index:21,confidence:0.02},{intent_index:22,confidence:0.02},{intent_index:23,confidence:0.02},{intent_index:24,confidence:0.02}]}
# 2026-07-14 00:04:41,822 INFO     [IPA_NLU_BOT] Success: Could you, um, please lower the seat heating? -> INTENT_DecreaseSeatHeating (0.80)
# 2026-07-14 00:04:42,325 INFO     =====[NSGA-II] Writing results to:
# 2026-07-14 00:04:42,327 INFO     ./results/NLU_test_nsga2_p5_g20_t-00-01-00_s1/NSGA-II/14-07-2026_00-02-59/
# 0.9189597513290261
# [write_results] results_folder is:  ./results/NLU_test_nsga2_p5_g20_t-00-01-00_s1/NSGA-II/14-07-2026_00-02-59/
# [create save folder] path: ./results/NLU_test_nsga2_p5_g20_t-00-01-00_s1/NSGA-II/14-07-2026_00-02-59/
# wandb: Adding directory to artifact (results/NLU_test_nsga2_p5_g20_t-00-01-00_s1/NSGA-II/14-07-2026_00-02-59)... Done. 0.0s
# {
#     "fail_rate": 0.29,
#     "num_diverse_fails": 1,
#     "tokens_spent": 108114
# }

# %% [markdown]
# # 4. Submit Your Code
#
# After your test run succeeds, rename the changed notebook file by appending your (group) name and send it to the address below.
#
# Address: lev.sorokin@tum.de
